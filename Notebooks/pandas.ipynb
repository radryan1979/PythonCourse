# %%
import numpy as np
import pandas as pd

from statsmodels import robust
import wquantiles

import seaborn as sns
import matplotlib.pylab as plt

# %%
violations = pd.read_csv('/Users/ryaneagan/DataSets/Restaurant_Inspection_Violations.csv')
crash = pd.read_csv('/Users/ryaneagan/DataSets/Public_Crash_Data.csv')

crash.count()
# Out:
# /var/folders/hg/by60chbx3gv__xtd5c1p9sxm0000gn/T/ipykernel_82345/803464436.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   crash = pd.read_csv('/Users/ryaneagan/DataSets/Public_Crash_Data.csv')
# CRASH DATETIME                                   445556
# DAY OF WEEK CODE                                 445559
# DAY OF WEEK DESCRIPTION                          445559
# CRASH CLASSIFICATION CODE                        445556
# CRASH CLASSIFICATION DESCRIPTION                 445534
# COLLISION ON PRIVATE PROPERTY                    445559
# PEDESTRIAN INVOLVED                              445559
# MANNER OF IMPACT CODE                            433983
# MANNER OF IMPACT DESCRIPTION                     433980
# ALCOHOL INVOLVED                                 445559
# DRUG INVOLVED                                    445559
# ROAD SURFACE CODE                                432853
# ...

# %%
dayWeek = pd.cut(crash['DAY OF WEEK CODE'],7)
print(dayWeek.value_counts())
# Out:
# (5.286, 6.143]    76143
# (4.429, 5.286]    66175
# (3.571, 4.429]    65285
# (2.714, 3.571]    64412
# (1.857, 2.714]    62946
# (6.143, 7.0]      61083
# (0.994, 1.857]    49515
# Name: DAY OF WEEK CODE, dtype: int64

# %%
ax = (crash['DAY OF WEEK CODE'].plot.hist(figsize=(4, 4)))
ax.set_xlabel('Day of Week')

plt.tight_layout()
plt.show()

# %%
plt.hist(crash['DAY OF WEEK CODE'], 7)
plt.xlabel('Day of Week')
plt.ylabel('Count')
plt.title('DE Crashes by Day of Week')
# Out:
# Text(0.5, 1.0, 'DE Crashes by Day of Week')

# %%
pd.mean(crash['ALCOHOL INVOLVED'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hg/by60chbx3gv__xtd5c1p9sxm0000gn/T/ipykernel_82345/972915281.py in <module>
# ----> 1 pd.mean(crash['ALCOHOL INVOLVED'])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'mean'
