# %% [markdown]
# # Plotting with Matplotlib

# %% [markdown]
# Matplotlib is the defactor plotting library for Python. <br>
# [Matplotlib](https://matplotlib.org)
#
# [Quickstart Guide](https://matplotlib.org/stable/tutorials/introductory/quick_start.html)<br>
# [Cheat Sheets](https://matplotlib.org/cheatsheets/)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 1)  # a figure with a 2x2 grid of Axes

# %%
fig, ax = plt.subplots()
ax.set_title('This Is My Graph')
ax.set_xlabel('The X Axes')
ax.set_ylabel('The Y Axes')
# Out:
# Text(0, 0.5, 'The Y Axes')

# %%
x = np.linspace(0, 100, 20)
z = np.linspace(-100, 10, 20)

[X, Z] = np.meshgrid(x, z)

g = 9.8

rho0 = 1000
drho_dx = 1/10e3
p_atm = 1e5

p = p_atm - g*(rho0 + drho_dx*X)*Z;



fig, ax = plt.subplots(1,1)
ax.contour(X, Z, p,10, cmap='PuBuGn')
ax.set_title('Color Contours')
ax.set_xlabel('Whatever You Want')
ax.set_ylabel('Pressure')
# Out:
# Text(0, 0.5, 'Pressure')

# %% [markdown]
# ## Histogram Example

# %%
the_data = [1,3,4,6,4,8,3,5,3,6,3,4,7,8,8,9,0,3,2,6,8,9,5,2,1,9,7,5,8,6,7,3,6,9,2,3,4,9,0,1,2,1,3,1,4,1,5,6]
bins = 10
plt.hist(the_data, bins)
plt.xlabel('Bins')
plt.ylabel('Count')
plt.title('A Histogram of Nothing')
# Out:
# Text(0.5, 1.0, 'A Histogram of Nothing')

# %% [markdown]
# An example of the stream plot from the Matplotlib website.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make a stream function:
X, Y = np.meshgrid(np.linspace(-3, 3, 256), np.linspace(-3, 3, 256))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)
# make U and V out of the streamfunction:
V = np.diff(Z[1:, :], axis=1)
U = -np.diff(Z[:, 1:], axis=0)

# plot:
fig, ax = plt.subplots()

ax.streamplot(X[1:, 1:], Y[1:, 1:], U, V)

plt.show()

# %% [markdown]
# Plotting a wave

# %%
x = np.linspace(0, 20, 201)
y = np.sin(x)

plt.figure(figsize = (8, 6))
plt.plot(x, y, 'b')
plt.ylabel('Amplitude')
plt.xlabel('Location (x)')
plt.show()
