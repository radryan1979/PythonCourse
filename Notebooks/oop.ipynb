# %% [markdown]
# # Object Oriented Programming
# ## aka Programming with Class
#
# The ideal way to reduce repeated code, improve program performance and simplify programming and code maintenance.

# %% [markdown]
# A basic function. Often gets used/called many times.

# %%
def myFunction(someArgument):
    theanswer = someArgument*23
    return theanswer

# %%
print(myFunction(44))
# Out:
# 1012

# %% [markdown]
# Classes are ways to create a template that can be used over and over again.

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def getInfo(self):
        return self.name, self.age
    
    def updateName(self, newName):
        self.name = newName

# %%
fido = Dog('Fido',3)

print(fido.getInfo())

print(fido.name)

print(fido.age)
# Out:
# ('Fido', 3)
# Fido
# 3

# %% [markdown]
# Why use classes? It's a great way to normalize data storage to ensure your data is consistent across
